# %%
import datetime
now = datetime.datetime.now()
print ("Updated on:")
print (now.strftime("%Y-%m-%d %H:%M"))
# Out:
# Updated on:
# 2019-07-12 15:01

# %% [markdown]
# # Project Name: Bacteria Cell Biology at the Air Liquid Interphase
#  ### __Main Question:__
#  Andres F Diaz Delgadillo
#
#
#  What is the role of cellulose during the colonization of the ALI by *Pseudomonas fluorescens SBW25*

# %% [markdown]
# ### _Motivation :
#
# Macroscopic observations of static microcosms inoculated with *Pseudomonas fluorescens SBW25* have shown that collective groups form at the Air Liquid Interphase (ALI) upon bacterial growth.
#
# The dynamics and emergence of collectives and the formation of groups is of interest for us to understand how cellulose helps biofilm growth and establishment of bacteria at the ALI.
#
# Here we study the initiation of these collectives prior biofilm establishment at the ALI and delve into the role of cellulose as biofilm initiator/facilitator. We use a device that serves the purpose to expose a triple point contact where bacteria attaches, the liquid media and air and quantify the interactions between bacterial secreted cellulose and the triple contact point.
#
# We utilize the Smooth Type wild type (SM) able to produce cellulose and form biofilms and the dwss or cellulose deficient mutant, whose cellulose operon WSS has been deleted from the genome.

# %%
FIGURESROOT="Y:/Diaz_Pichugina_Pseudomona/Figures/Figure_1_WSS_promotes_colonization_ALI/"
Image(filename = FIGURESROOT + "FIgure1A_setup.jpg", width=800, height=800)

# %% [markdown]
# 1. FIGURE SETUP: The setup profits from three axis to where bacteria deposition occurs; in A a fully assembled setup is shown and exposes a confined cavity to a microscope objective using a high numerical aperture (1.3 NA). In B, the image shows a top view of the [x-axis,y-axis] of the setup with a frame in red, depicting the observation area. C. is a cross section in [z-axis, y-axis] showing the lateral view of the liquid media and the triple point angle. D, is a zoomed view of the red frame depicted in B, showing single bacteria colonizing the triple point angle.

# %%
from IPython.display import Image
FIGURESROOT="Y:/Diaz_Pichugina_Pseudomona/Figures/Figure_1_WSS_promotes_colonization_ALI/"
Image(filename = FIGURESROOT + "FIgure1B_SM_vs_dwss.jpg", width=800, height=800)

# %% [markdown]
# 2. FIGURE DESCRIPTION: Image showing the [y-axis, x-axis] comparing the wild type SBW25 (SM) WSS (+) bacterium vs SBW25 cellulose (-) after 14 hours of incubation at 27 C. The  air pressure of the chamber is 1.2 atmospheres and oxygen        concentration is 20% its volume. In B a kyomgraph comparing both strains, shows the differences in colonization area where both prone to aerotaxis, densely populate the upper layers whereas WSS (-) is unable to remain attached in place at the lower layers.

# %%
FIGURESROOT="Y:/Diaz_Pichugina_Pseudomona/Figures/Figure_1_WSS_promotes_colonization_ALI/"
Image(filename = FIGURESROOT + "FIgure1C_colonization_rate_area.jpg", width=800, height=800)

# %% [markdown]
# 3. FIGURE DESCRIPTION: Figure shows area colonization growth dynamics between dwss in (red) and SM in (blue) throughout 15 hours of experiment. Rates were obtained by fittin data using an exponential growth curve model [parameters] and colonization rates estimated for dwss r<0.001 and SM r>0.01. Experiments were done using 10x10^6 cells. Initial conditions for the experiments correspond to an Optical Density of 0.1 standardized against a sterile solution containing beads of 1um size in glycerol 10% and Kings Broth Media to maintain experimental consistency and variability among replicates.

# %%
FIGURESROOT="Y:/Diaz_Pichugina_Pseudomona/Figures/Figure_1_WSS_promotes_colonization_ALI/"
Image(filename = FIGURESROOT + "FIGURE_1X_Area_per_Layer_bar_plot.jpg", width=800, height=800)

# %% [markdown]
# 5. FIGURE DESCRIPTION:

# %%
FIGURESROOT="Y:/Diaz_Pichugina_Pseudomona/Figures/Figure_1_WSS_promotes_colonization_ALI/"
Image(filename = FIGURESROOT + "FIGURE 1D_Area_per_Layer.jpg", width=800, height=800)

# %% [markdown]
# 4. FIGURE DESCRIPTION: Biofilm colonization success at different distances from the triple point at the Air Liquid Glass (ALG) interphase. The y-axis shows the colonization area in microns squared covered by bacteria. The x-axis shows the time intervals in up to 15 hrs of bacteria growth. Data shows differences in colonization success between dwss and SM. In blue wild type SBW25 SM is successful colonizing all layers, while dwss in red is unable to colonize the lower layers of the ALG interphase.
